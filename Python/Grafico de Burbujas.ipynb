# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
np.random.seed(0)
df = pd.read_csv(r"C:\Users\danie\OneDrive\Documentos\Cursos\python_ds_linkedin\base_datos_2008.csv", nrows = 1000000)
df.sample(frac=1).head(100)
# Out:
#         Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 157105  2008      1          11          5    615.0         615    955.0
# 374554  2008      1          29          2   1340.0        1345   2050.0
# 688694  2008      2          28          4   1354.0        1350   1444.0
# 265381  2008      1           8          2    938.0         940   1110.0
# 955415  2008      2          25          1   1411.0        1411   1621.0
# ...      ...    ...         ...        ...      ...         ...      ...
# 567152  2008      1           6          7   1642.0        1625   1959.0
# 474312  2008      1          10          4   2102.0        2104   2232.0
# 611862  2008      2           4          1    605.0         605    603.0
# 591853  2008      1           4          5   1754.0        1759   2010.0
# 151774  2008      1           3          4   1145.0        1110   1332.0
#
#         CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %% [markdown]
# Procedemos a crear el gráfico

# %%
plt.scatter(x= df.DayofMonth, y= df.ArrDelay, s= df.Distance)

# %%
#Ahora agregaremos el parámetro "alpha" el cual hace referencia a la transparencia de las burbujas
plt.scatter(x= df.DayofMonth, y= df.ArrDelay, s= df.Distance, alpha = 0.3)

# %%
#Quiero ver los días de semana
plt.scatter(x= df.DayofMonth, y= df.ArrDelay, s= df.Distance, c=df.DayOfWeek.isin([6,7]))
plt.title("Retrasos en EEUU")
plt.xlabel("Day of Month")
plt.ylabel("Retraso al llegar")
plt.ylim([0, 1700])
plt.xticks([0, 15, 30])
plt.text(x= 28, y= 1200, s="Mi vuelo")
# Out:
# Text(28, 1200, 'Mi vuelo')

# %%
plt.ylim([0,1500])
# Out:
# (0.0, 1500.0)
