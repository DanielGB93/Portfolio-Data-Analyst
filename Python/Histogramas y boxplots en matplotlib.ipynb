# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv(r"C:\Users\danie\OneDrive\Documentos\Cursos\python_ds_linkedin\base_datos_2008.csv")

# %%
#borraremos todos los campos vacíos en las columnas que trabajaremos
df.dropna(inplace= True, subset =["ArrDelay", "DepDelay", "Distance"])

# %%
sns.distplot(df["Distance"])
# Out:
# C:\Users\danie\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Distance', ylabel='Density'>

# %%
sns.distplot(df["Distance"], kde = False)
# Out:
# C:\Users\danie\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Distance'>

# %%
sns.distplot(df["Distance"], kde = False, bins = 100)
# Out:
# <AxesSubplot:xlabel='Distance'>

# %%
#Comparar dos distribuciones
sns.distplot(df["Distance"])
sns.distplot(df["ArrDelay"])
plt.xlim([-300, 300])
# Out:
# C:\Users\danie\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\danie\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# (-300.0, 300.0)

# %%
df2= df[df["Origin"].isin(["ATL"])].sample(frac=1).head(100)

# %%
sns.boxplot(x="DepDelay", y ="Origin", data = df2)
# Out:
# <AxesSubplot:xlabel='DepDelay', ylabel='Origin'>
